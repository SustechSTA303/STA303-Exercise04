# %% [markdown]
# # Exercise 04:  Route Planning

# %% [markdown]
# In route planning, the objective is to find the best way to get from point A to point B (think Google Maps). In this exercise, we will try top of the classic shortest path problem.

# %% [markdown]
# ### Basic Imports

# %%
from queue import PriorityQueue

# %% [markdown]
# ``PriorityQueue`` implements a priority queue data structure, where elements are typically tuples of the form (priority, item). The entries are kept sorted by priority, and the queue retrieves elements starting with the lowest priority item. For details, please refer to https://docs.python.org/3/library/queue.html.

# %% [markdown]
# ### Task 1: Implement Uniform Cost Search Algorithm
#
# Complete the implementation of the Uniform Cost Search (UCS) algorithm. You are provided with a partially completed function. Your task is to fill in the missing logic in the loop that processes nodes from the priority .

# %%
def ucs(graph, home, destination):
    """
    Perform Uniform Cost Search on a graph from a start location (home) to a goal location (destination).

    Parameters:
    graph (dict): A dictionary representation of the graph where keys are location names and values
                  are dictionaries of neighbors with their associated costs.
    home (str): The starting location in the graph.
    destination (str): The goal location to reach in the graph.

    Returns:
    tuple: result(tuple) : A tuple containing the total cost (int) and path as a list of locations (str) from 'home' to 'destination'.
    """
    if home not in graph:
        raise TypeError(str(home) + ' not found in graph!')
    if destination not in graph:
        raise TypeError(str(destination) + ' not found in graph!')

    q = PriorityQueue()
    q.put((0, home, [home]))
    
    vis = {}
    
    while not q.empty():
        ##################### Write your answer here ##################
        nval, now, pth = q.get()
        if now in vis:
            continue
        vis[now] = nval
        for c, v in graph[now].items():
            if c in vis:
                continue
            if c == destination:
                return pth + [c], v + nval
            q.put((v + nval, c, pth + [c]))
        ###############################################################
        # Your task: Complete the implementation here.
        # - Check if the current location is the goal (destination).
        # - Iterate over the neighbors of the current location.
        # - For each neighbor, calculate the total cost from the start location.
        # - Add the neighbor to the priority queue if it hasn't been visited
        
    # If the goal is not reachable, return None
    return None

# %% [markdown]
# ### Test Phase
# Let us find the shortest path from Anyang to HongKong.

# %%
file = open("maps.txt","r")
lines = file.readlines()
graph = {}
nodes = []
for line in lines:
    token = line.split()
    node = token[0]
    nodes.append(node)
    graph[node] = {}
    for i in range(1, len(token)-1, 2):
        graph[node][token[i]] = int(token[i + 1])

for node1 in nodes:
    for node2 in nodes:
        if node1 == node2:
            continue
        result=ucs(graph, node1, node2)
        if result:
            path, cost = result
            formatted_path = " -> ".join(path)  # Formats the path as 'A -> B -> C'
            print(f"Shortest path: {formatted_path} with total cost: {cost}")
        else:
            print("Path not found")
# Out:
# Shortest path: Anyang -> Zhengzhou with total cost: 200
# Shortest path: Anyang -> Beijing with total cost: 500
# Shortest path: Anyang -> Wuhan with total cost: 600
# Shortest path: Anyang -> Zhengzhou -> Nanchang with total cost: 1000
# Shortest path: Anyang -> Zhengzhou -> Hefei with total cost: 320
# Shortest path: Anyang -> Beijing -> Xian with total cost: 1200
# Shortest path: Anyang -> Zhengzhou -> Nanchang -> Shenzhen with total cost: 1400
# Shortest path: Anyang -> Zhengzhou -> Nanchang -> Shenzhen -> HongKong with total cost: 1450
# Shortest path: Anyang -> Zhengzhou -> Nanchang -> Xiamen with total cost: 1700
# Shortest path: Zhengzhou -> Anyang with total cost: 200
# Shortest path: Zhengzhou -> Anyang -> Beijing with total cost: 700
# Shortest path: Zhengzhou -> Hefei -> Wuhan with total cost: 570
# Shortest path: Zhengzhou -> Nanchang with total cost: 800
# Shortest path: Zhengzhou -> Hefei with total cost: 120
# Shortest path: Zhengzhou -> Anyang -> Beijing -> Xian with total cost: 1400
# Shortest path: Zhengzhou -> Nanchang -> Shenzhen with total cost: 1200
# Shortest path: Zhengzhou -> Nanchang -> Shenzhen -> HongKong with total cost: 1250
# Shortest path: Zhengzhou -> Nanchang -> Xiamen with total cost: 1500
# Shortest path: Beijing -> Anyang with total cost: 500
# Shortest path: Beijing -> Anyang -> Zhengzhou with total cost: 700
# Shortest path: Beijing -> Wuhan with total cost: 900
# Shortest path: Beijing -> Anyang -> Zhengzhou -> Nanchang with total cost: 1500
# Shortest path: Beijing -> Anyang -> Zhengzhou -> Hefei with total cost: 820
# Shortest path: Beijing -> Xian with total cost: 700
# Shortest path: Beijing -> Anyang -> Zhengzhou -> Nanchang -> Shenzhen with total cost: 1900
# Shortest path: Beijing -> Anyang -> Zhengzhou -> Nanchang -> Shenzhen -> HongKong with total cost: 1950
# Shortest path: Beijing -> Anyang -> Zhengzhou -> Nanchang -> Xiamen with total cost: 2200
# Shortest path: Wuhan -> Anyang with total cost: 600
# Shortest path: Wuhan -> Hefei -> Zhengzhou with total cost: 570
# Shortest path: Wuhan -> Beijing with total cost: 900
# Shortest path: Wuhan -> Nanchang with total cost: 900
# Shortest path: Wuhan -> Hefei with total cost: 450
# Shortest path: Wuhan -> Beijing -> Xian with total cost: 1600
# Shortest path: Wuhan -> Nanchang -> Shenzhen with total cost: 1300
# Shortest path: Wuhan -> Nanchang -> Shenzhen -> HongKong with total cost: 1350
# Shortest path: Wuhan -> Nanchang -> Xiamen with total cost: 1600
# Shortest path: Nanchang -> Zhengzhou -> Anyang with total cost: 1000
# Shortest path: Nanchang -> Zhengzhou with total cost: 800
# Shortest path: Nanchang -> Wuhan -> Beijing with total cost: 1800
# Shortest path: Nanchang -> Wuhan with total cost: 900
# Shortest path: Nanchang -> Zhengzhou -> Hefei with total cost: 920
# Shortest path: Nanchang -> Zhengzhou -> Anyang -> Beijing -> Xian with total cost: 2200
# Shortest path: Nanchang -> Shenzhen with total cost: 400
# Shortest path: Nanchang -> Shenzhen -> HongKong with total cost: 450
# Shortest path: Nanchang -> Xiamen with total cost: 700
# Shortest path: Hefei -> Zhengzhou -> Anyang with total cost: 320
# Shortest path: Hefei -> Zhengzhou with total cost: 120
# Shortest path: Hefei -> Zhengzhou -> Anyang -> Beijing with total cost: 820
# Shortest path: Hefei -> Wuhan with total cost: 450
# Shortest path: Hefei -> Zhengzhou -> Nanchang with total cost: 920
# Shortest path: Hefei -> Zhengzhou -> Anyang -> Beijing -> Xian with total cost: 1520
# Shortest path: Hefei -> Zhengzhou -> Nanchang -> Shenzhen with total cost: 1320
# Shortest path: Hefei -> Zhengzhou -> Nanchang -> Shenzhen -> HongKong with total cost: 1370
# Shortest path: Hefei -> Zhengzhou -> Nanchang -> Xiamen with total cost: 1620
# Shortest path: Xian -> Beijing -> Anyang with total cost: 1200
# Shortest path: Xian -> Beijing -> Anyang -> Zhengzhou with total cost: 1400
# Shortest path: Xian -> Beijing with total cost: 700
# Shortest path: Xian -> Beijing -> Wuhan with total cost: 1600
# Shortest path: Xian -> Beijing -> Anyang -> Zhengzhou -> Nanchang with total cost: 2200
# Shortest path: Xian -> Beijing -> Anyang -> Zhengzhou -> Hefei with total cost: 1520
# Shortest path: Xian -> Beijing -> Anyang -> Zhengzhou -> Nanchang -> Shenzhen with total cost: 2600
# Shortest path: Xian -> Beijing -> Anyang -> Zhengzhou -> Nanchang -> Shenzhen -> HongKong with total cost: 2650
# Shortest path: Xian -> Beijing -> Anyang -> Zhengzhou -> Nanchang -> Xiamen with total cost: 2900
# Shortest path: Shenzhen -> Nanchang -> Zhengzhou -> Anyang with total cost: 1400
# Shortest path: Shenzhen -> Nanchang -> Zhengzhou with total cost: 1200
# Shortest path: Shenzhen -> Nanchang -> Wuhan -> Beijing with total cost: 2200
# Shortest path: Shenzhen -> Nanchang -> Wuhan with total cost: 1300
# Shortest path: Shenzhen -> Nanchang with total cost: 400
# Shortest path: Shenzhen -> Nanchang -> Zhengzhou -> Hefei with total cost: 1320
# Shortest path: Shenzhen -> Nanchang -> Zhengzhou -> Anyang -> Beijing -> Xian with total cost: 2600
# Shortest path: Shenzhen -> HongKong with total cost: 50
# Shortest path: Shenzhen -> HongKong -> Xiamen with total cost: 550
# Shortest path: HongKong -> Shenzhen -> Nanchang -> Zhengzhou -> Anyang with total cost: 1450
# Shortest path: HongKong -> Shenzhen -> Nanchang -> Zhengzhou with total cost: 1250
# Shortest path: HongKong -> Shenzhen -> Nanchang -> Wuhan -> Beijing with total cost: 2250
# Shortest path: HongKong -> Shenzhen -> Nanchang -> Wuhan with total cost: 1350
# Shortest path: HongKong -> Shenzhen -> Nanchang with total cost: 450
# Shortest path: HongKong -> Shenzhen -> Nanchang -> Zhengzhou -> Hefei with total cost: 1370
# Shortest path: HongKong -> Shenzhen -> Nanchang -> Zhengzhou -> Anyang -> Beijing -> Xian with total cost: 2650
# Shortest path: HongKong -> Shenzhen with total cost: 50
# Shortest path: HongKong -> Xiamen with total cost: 500
# Shortest path: Xiamen -> Nanchang -> Zhengzhou -> Anyang with total cost: 1700
# Shortest path: Xiamen -> Nanchang -> Zhengzhou with total cost: 1500
# Shortest path: Xiamen -> Nanchang -> Wuhan -> Beijing with total cost: 2500
# Shortest path: Xiamen -> Nanchang -> Wuhan with total cost: 1600
# Shortest path: Xiamen -> Nanchang with total cost: 700
# Shortest path: Xiamen -> Nanchang -> Zhengzhou -> Hefei with total cost: 1620
# Shortest path: Xiamen -> Nanchang -> Zhengzhou -> Anyang -> Beijing -> Xian with total cost: 2900
# Shortest path: Xiamen -> HongKong -> Shenzhen with total cost: 550
# Shortest path: Xiamen -> HongKong with total cost: 500
